# %% [markdown]
# # Load different type of Data

# %% [markdown]
# 1. Load CSV data
# 2. Load Table data
# 3. Load Excel Data
# 4. Load SQL data
# 5. Load JSON data
# 6. Load XML and HTML data
# 7. Load Clipboard data
# 8. Load dataframe
# 9. Load data from Github
# 10. Load Binary data Formats
# 11. Load HDF5 data Formats
# 12. Web APIs data
# 13. Set the working directory
# 14. with open data
# 15. zip folder
# 16. Create date time
# 17. Load data from SQL lite, sql, mongodb

# %%
#loading required libraries
import numpy as np
import pandas as pd
import os
from os import path

# %% [markdown]
# # Set the working directory

# %%
workingdir=os.getcwd()
path=workingdir+'/examples/ex1.csv'
path
# Out:
# '/Users/mdsanowarhossain/Documents/python/Pandas/Data Ananlysis/examples/examples/ex1.csv'

# %%
pwd
# Out:
# '/Users/mdsanowarhossain/Documents/python/Pandas/Data Ananlysis/examples'

# %% [markdown]
# # Load CSV Data

# %%
df=pd.read_csv("ex1.csv")

# %%
#show 1st five data
df.head()
# Out:
#    a   b   c   d message
# 0  1   2   3   4   hello
# 1  5   6   7   8   world
# 2  9  10  11  12     foo

# %%
#check the data type
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
#show last five row
df.tail()
# Out:
#    a   b   c   d message
# 0  1   2   3   4   hello
# 1  5   6   7   8   world
# 2  9  10  11  12     foo

# %%
df.head()
# Out:
#    a   b   c   d message
# 0  1   2   3   4   hello
# 1  5   6   7   8   world
# 2  9  10  11  12     foo

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# # Load Table data using separate by tab

# %%
df2=pd.read_csv("test.tsv",sep='\t')

# %%
df2
# Out:
#         test   test test.1 test.2 test.3
# sudh    sudh   sudh   sudh   sudh   sudh
# kumar  kumar  kumar  kumar  kumar  kumar

# %% [markdown]
# # Load CSV data using separate by coma

# %%
#load csv data by table_table
df3=pd.read_table("ex1.csv",sep=',')

# %%
df3
# Out:
#    a   b   c   d message
# 0  1   2   3   4   hello
# 1  5   6   7   8   world
# 2  9  10  11  12     foo

# %% [markdown]
# # Load CSV data without using header

# %%
df5=pd.read_csv("ex1.csv",header=None)

# %%
df5
# Out:
#    0   1   2   3        4
# 0  a   b   c   d  message
# 1  1   2   3   4    hello
# 2  5   6   7   8    world
# 3  9  10  11  12      foo

# %% [markdown]
# # Load CSV data with header by manually define names

# %%
df6=pd.read_csv("ex2.csv",names=['a','b','c','d'])

# %%
df6
# Out:
#     a   b   c      d
# 1   2   3   4  hello
# 5   6   7   8  world
# 9  10  11  12    foo

# %% [markdown]
# # Load CSV data using multilebel indexes

# %%
index_data=pd.read_csv("csv_mindex.csv",index_col=['key1','key2'])
index_data
# Out:
#            value1  value2
# key1 key2
# one  a          1       2
#      b          3       4
#      c          5       6
#      d          7       8
# two  a          9      10
#      b         11      12
#      c         13      14
#      d         15      16

# %% [markdown]
# # Load CSV data which are not read able format; here row 0,2,3 are not readable data

# %%
df7=pd.read_csv("ex4.csv")
df7
# Out:
#                                                                       # hey!
# a                                                  b        c   d    message
# # just wanted to make things more difficult for... NaN      NaN NaN      NaN
# # who reads CSV files with computers                anyway? NaN NaN      NaN
# 1                                                  2        3   4      hello
# 5                                                  6        7   8      world
# 9                                                  10       11  12       foo

# %%
df8=pd.read_csv("ex4.csv",skiprows=[0,2,3],names=['x','y','z','w'])
df8
# Out:
#     x   y   z        w
# a   b   c   d  message
# 1   2   3   4    hello
# 5   6   7   8    world
# 9  10  11  12      foo

# %% [markdown]
# # Load CSV data which is replaced NaN value by True or False

# %%
df9=pd.read_csv("ex5.csv")
df9
pd.isnull(df9)
# Out:
#    something      a      b      c      d  message
# 0      False  False  False  False  False     True
# 1      False  False  False   True  False    False
# 2      False  False  False  False  False    False

# %%
df11=pd.read_csv("ex5.csv")
df11
# Out:
#   something  a   b     c   d message
# 0       one  1   2   3.0   4     NaN
# 1       two  5   6   NaN   8   world
# 2     three  9  10  11.0  12     foo

# %%
df10=pd.read_csv("ex5.csv",na_values=['NULL'])
df10
# Out:
#   something  a   b     c   d message
# 0       one  1   2   3.0   4     NaN
# 1       two  5   6   NaN   8   world
# 2     three  9  10  11.0  12     foo

# %% [markdown]
# # Load Excel data with different sheet and index_col

# %%
#!pip install openpyxl

# %%
df11=pd.read_excel("ex1.xlsx",index_col=[0],sheet_name="Sheet2")
df11
# Out:
#    a   b   c   d message
# 0  1   2   3   4   hello
# 1  5   6   7   8   world
# 2  9  10  11  12     foo

# %% [markdown]
# # Load HTML Data
#
# * read data from the specific url
# * more html data will load by beautifull suop

# %%
url="https://www.basketball-reference.com/leagues/NBA_2019.html"
df=pd.read_html(url)
df12=df[0]#convert data frame from list
df12.head()
#df['W']#this is list;series data
df12[['W','L']]# this is data frame
# Out:
#      W   L
# 0   60  22
# 1   58  24
# 2   51  31
# 3   49  33
# 4   48  34
# 5   42  40
# 6   42  40
# 7   41  41
# 8   39  43
# 9   39  43
# 10  32  50
# 11  29  53
# 12  22  60
# 13  19  63
# 14  17  65

# %% [markdown]
# # Load CSV data using GitHub link

# %%
df13=pd.read_csv("https://raw.githubusercontent.com/HossainSanowar-Github/titanic_dataset/main/train.csv")
df13
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df13.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
df13[['Name','Sex','Age']]
# Out:
#                                                   Name     Sex   Age
# 0                              Braund, Mr. Owen Harris    male  22.0
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 2                               Heikkinen, Miss. Laina  female  26.0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 4                             Allen, Mr. William Henry    male  35.0
# ..                                                 ...     ...   ...
# 886                              Montvila, Rev. Juozas    male  27.0
# 887                       Graham, Miss. Margaret Edith  female  19.0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female   NaN
# 889                              Behr, Mr. Karl Howell    male  26.0
# 890                                Dooley, Mr. Patrick    male  32.0
#
# [891 rows x 3 columns]

# %%
df13[['Name','Age','Sex']].head()
# Out:
#                                                 Name   Age     Sex
# 0                            Braund, Mr. Owen Harris  22.0    male
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  38.0  female
# 2                             Heikkinen, Miss. Laina  26.0  female
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  35.0  female
# 4                           Allen, Mr. William Henry  35.0    male

# %% [markdown]
# # Load CSV data and display 5 and 10 rows

# %%
df14 = pd.read_csv('ex6.csv')
df14.head()
# Out:
#         one       two     three      four key
# 0  0.467976 -0.038649 -0.295344 -1.824726   L
# 1 -0.358893  1.404453  0.704965 -0.200638   B
# 2 -0.501840  0.659254 -0.421691 -0.057688   G
# 3  0.204886  1.074134  1.388361 -0.982404   R
# 4  0.354628 -0.133116  0.283763 -0.837063   Q

# %%
#display can be 5, 10 rows
#reduce the memory when the loading data
df15 = pd.read_csv('ex6.csv',nrows=10)
df15
# Out:
#         one       two     three      four key
# 0  0.467976 -0.038649 -0.295344 -1.824726   L
# 1 -0.358893  1.404453  0.704965 -0.200638   B
# 2 -0.501840  0.659254 -0.421691 -0.057688   G
# 3  0.204886  1.074134  1.388361 -0.982404   R
# 4  0.354628 -0.133116  0.283763 -0.837063   Q
# 5  1.817480  0.742273  0.419395 -2.251035   Q
# 6 -0.776764  0.935518 -0.332872 -1.875641   U
# 7 -0.913135  1.530624 -0.572657  0.477252   K
# 8  0.358480 -0.497572 -0.367016  0.507702   S
# 9 -1.740877 -1.160417 -1.637830  2.172201   G

# %% [markdown]
# # Try to define the Data size

# %%
df16 = pd.read_csv('ex6.csv', chunksize=1000)
df16

# %% [markdown]
# # Load csv data by with open format

# %%
import csv
with open("ex7.csv") as f:
    df17=csv.reader(f)
df17

# %%
try:
    for i in df17:
        print(i)
except Exception as e:
    print(e)
# Out:
# I/O operation on closed file.

# %% [markdown]
# #### The above block is not worked, because the file is already closed

# %% [markdown]
# # Load csv data by open format

# %%
f1=open("ex7.csv")
df18=csv.reader(f1)
df18

# %%
for i in df18:
    print(i)
# Out:
# ['a', 'b', 'c']
# ['1', '2', '3']
# ['1', '2', '3']

# %%
with open('ex7.csv') as f:
    lines=list(csv.reader(f))

# %%
header, values = lines[0],lines[1:]
print(header)
print(values)
# Out:
# ['a', 'b', 'c']
# [['1', '2', '3'], ['1', '2', '3']]

# %% [markdown]
# # Zip folders

# %%
zip(header, values)

# %%
list(zip(header, values))
# Out:
# [('a', ['1', '2', '3']), ('b', ['1', '2', '3'])]

# %%
list(zip(*values))
# Out:
# [('1', '1'), ('2', '2'), ('3', '3')]

# %%
list(zip(header, zip(*values)))
# Out:
# [('a', ('1', '1')), ('b', ('2', '2')), ('c', ('3', '3'))]

# %%
data_dict={h:v for h,v in zip(header,zip(*values))}
data_dict
# Out:
# {'a': ('1', '1'), 'b': ('2', '2'), 'c': ('3', '3')}

# %%
c,n=('a',(1,1))

# %%
n
# Out:
# (1, 1)

# %%
l1=['a','b','c']
l2=[1,2,3]

# %%
for i in zip(l1,l2):
    print(i)
# Out:
# ('a', 1)
# ('b', 2)
# ('c', 3)

# %%
{k:v for k,v in zip(l1,l2)}
# Out:
# {'a': 1, 'b': 2, 'c': 3}

# %% [markdown]
# # Load JSON Data

# %% [markdown]
# http://jsonviewer.stack.hu/

# %%
obj = """
{"name": "Wes",
 "places_lived": ["United States", "Spain", "Germany"],
 "pet": null,
 "siblings": [{"name": "Scott", "age": 30, "pets": ["Zeus", "Zuko"]},
              {"name": "Katie", "age": 38,
               "pets": ["Sixes", "Stache", "Cisco"]}]
}
"""

# %%
#convert str to dict
import json
df19 = json.loads(obj)
df19
# Out:
# {'name': 'Wes',
#  'places_lived': ['United States', 'Spain', 'Germany'],
#  'pet': None,
#  'siblings': [{'name': 'Scott', 'age': 30, 'pets': ['Zeus', 'Zuko']},
#   {'name': 'Katie', 'age': 38, 'pets': ['Sixes', 'Stache', 'Cisco']}]}

# %%
siblings = pd.DataFrame(df19['siblings'])
siblings
# Out:
#     name  age                    pets
# 0  Scott   30            [Zeus, Zuko]
# 1  Katie   38  [Sixes, Stache, Cisco]

# %% [markdown]
# # convert dict to str

# %%
asjson=json.dumps(df19)
asjson
# Out:
# '{"name": "Wes", "places_lived": ["United States", "Spain", "Germany"], "pet": null, "siblings": [{"name": "Scott", "age": 30, "pets": ["Zeus", "Zuko"]}, {"name": "Katie", "age": 38, "pets": ["Sixes", "Stache", "Cisco"]}]}'

# %%
siblings = pd.DataFrame(df19['siblings'])
siblings
# Out:
#     name  age                    pets
# 0  Scott   30            [Zeus, Zuko]
# 1  Katie   38  [Sixes, Stache, Cisco]

# %%
df20 = pd.read_json('example.json')
df20
# Out:
#    a  b  c
# 0  1  2  3
# 1  4  5  6
# 2  7  8  9

# %% [markdown]
# # Save json data

# %%
print(df20.to_json())
print(df20.to_json(orient='records'))
# Out:
# {"a":{"0":1,"1":4,"2":7},"b":{"0":2,"1":5,"2":8},"c":{"0":3,"1":6,"2":9}}
# [{"a":1,"b":2,"c":3},{"a":4,"b":5,"c":6},{"a":7,"b":8,"c":9}]

# %% [markdown]
# # Load XML and HTML data using Web Scaping

# %%
df21 = pd.read_html('fdic_failed_bank_list.html')
print(len(df21))
df21=df21[0]
df21
# Out:
# 1
#                              Bank Name             City  ST   CERT  \
# 0                          Allied Bank         Mulberry  AR     91
# 1         The Woodbury Banking Company         Woodbury  GA  11297
# 2               First CornerStone Bank  King of Prussia  PA  35312
# 3                   Trust Company Bank          Memphis  TN   9956
# 4           North Milwaukee State Bank        Milwaukee  WI  20364
# ..                                 ...              ...  ..    ...
# 542                 Superior Bank, FSB         Hinsdale  IL  32646
# 543                Malta National Bank            Malta  OH   6629
# 544    First Alliance Bank & Trust Co.       Manchester  NH  34264
# 545  National State Bank of Metropolis       Metropolis  IL   3815
# 546                   Bank of Honolulu         Honolulu  HI  21029
#
#                    Acquiring Institution        Closing Date  \
# 0                           Today's Bank  September 23, 2016
# ...

# %% [markdown]
# # Create DateTime

# %%
close_date=pd.to_datetime(df21['Closing Date'])
close_date
# Out:
# 0     2016-09-23
# 1     2016-08-19
# 2     2016-05-06
# 3     2016-04-29
# 4     2016-03-11
#          ...
# 542   2001-07-27
# 543   2001-05-03
# 544   2001-02-02
# 545   2000-12-14
# 546   2000-10-13
# Name: Closing Date, Length: 547, dtype: datetime64[ns]

# %% [markdown]
# # Create Year with count value

# %%
# can create year, month, day, quater, hour, minitue, second
close_date.dt.year
close_date.dt.year.value_counts()
# Out:
# 2010    157
# 2009    140
# 2011     92
# 2012     51
# 2008     25
# 2013     24
# 2014     18
# 2002     11
# 2015      8
# 2016      5
# 2004      4
# 2001      4
# 2007      3
# 2003      3
# 2000      2
# Name: Closing Date, dtype: int64

# %% [markdown]
# # Load Binary Data Formats using csv
# * Load CSV data
# * Save pickle format data and load it

# %%
df22= pd.read_csv('ex1.csv')
df22.to_pickle('df22_pickle')

# %%
pd.read_pickle('df22_pickle')
# Out:
#    a   b   c   d message
# 0  1   2   3   4   hello
# 1  5   6   7   8   world
# 2  9  10  11  12     foo

# %% [markdown]
# # Load HDF5 Format data

# %%
#!pip install tables

# %%
df23=pd.DataFrame({'a':np.random.randn(100)})
store=pd.HDFStore('mydata.h5')
store['obj1']=df23
store['obj1_col']=df23['a']
df23
print(store)
# Out:
# <class 'pandas.io.pytables.HDFStore'>
# File path: mydata.h5

# %% [markdown]
# # Load web APIs data

# %%
import requests
url='https://api.github.com/repos/pandas-dev/pandas/issues'
df24=requests.get(url)
df24
# Out:
# <Response [200]>

# %%
data=df24.json()
data[0]['user']
# Out:
# {'login': 'weikhor',
#  'id': 36619387,
#  'node_id': 'MDQ6VXNlcjM2NjE5Mzg3',
#  'avatar_url': 'https://avatars.githubusercontent.com/u/36619387?v=4',
#  'gravatar_id': '',
#  'url': 'https://api.github.com/users/weikhor',
#  'html_url': 'https://github.com/weikhor',
#  'followers_url': 'https://api.github.com/users/weikhor/followers',
#  'following_url': 'https://api.github.com/users/weikhor/following{/other_user}',
#  'gists_url': 'https://api.github.com/users/weikhor/gists{/gist_id}',
#  'starred_url': 'https://api.github.com/users/weikhor/starred{/owner}{/repo}',
#  'subscriptions_url': 'https://api.github.com/users/weikhor/subscriptions',
#  'organizations_url': 'https://api.github.com/users/weikhor/orgs',
#  'repos_url': 'https://api.github.com/users/weikhor/repos',
#  'events_url': 'https://api.github.com/users/weikhor/events{/privacy}',
#  'received_events_url': 'https://api.github.com/users/weikhor/received_events',
#  'type': 'User',
#  'site_admin': False}

# %%
df25=pd.DataFrame(data,columns=['number','title','labels','state'])
df25
# Out:
#     number                                              title  \
# 0    46162  Bug Fix GroupBy.describe produces inconsistent...
# 1    46161                              Update test_fillna.py
# 2    46160  Backport PR #46124 on branch 1.4.x (DOC: Impro...
# 3    46159  Backport PR #45902 on branch 1.4.x (Use Mamba ...
# 4    46158  Backport PR #46118 on branch 1.4.x (CI: Align ...
# 5    46156         BUG: MultiIndex slicing with negative step
# 6    46154  BUG: Converting `pd.Timestamp.min` to equivale...
# 7    46153  Adding tests for IntervalArray.unique() for Da...
# 8    46152     BUG: Styler cannot accept semicolon in CSS val
# 9    46149  PERF: Series.fillna (that is part of DataFrame...
# 10   46147                          ENH: Enumeration grouping
# 11   46145  BUG: dataframe/series.isna().sum() overcounts ...
# 12   46144    CI/TST: Flaky test `test_union_different_types`
# 13   46142         REF: combine masked_cummin_max, cummin_max
# ...

# %% [markdown]
# # How to get data of labels columns using dataframe

# %%
#solution 1
import requests
url = 'https://api.github.com/repos/pandas-dev/pandas/issues'
df26=requests.get(url)

df27=df26.json()
masterDF=pd.DataFrame(columns=['id','node_id','url','name','color','default','description'])
for i in range(30):
    s= pd.DataFrame(df27[i]['labels'],columns=['id','node_id','url','name','color','default','description'])
    masterDF=masterDF.append(s,ignore_index=True)
masterDF
# Out:
#             id                   node_id  \
# 0       134699      MDU6TGFiZWwxMzQ2OTk=
# 1     48070600  MDU6TGFiZWw0ODA3MDYwMA==
# 2     48070600  MDU6TGFiZWw0ODA3MDYwMA==
# 3        76811      MDU6TGFiZWw3NjgxMQ==
# 4      2822098      MDU6TGFiZWwyODIyMDk4
# 5     71268330  MDU6TGFiZWw3MTI2ODMzMA==
# 6        76811      MDU6TGFiZWw3NjgxMQ==
# 7   1954720290  MDU6TGFiZWwxOTU0NzIwMjkw
# 8       127685      MDU6TGFiZWwxMjc2ODU=
# 9    150096370  MDU6TGFiZWwxNTAwOTYzNzA=
# 10       76811      MDU6TGFiZWw3NjgxMQ==
# 11  1954720290  MDU6TGFiZWwxOTU0NzIwMjkw
# 12     8935311      MDU6TGFiZWw4OTM1MzEx
# 13  1954720290  MDU6TGFiZWwxOTU0NzIwMjkw
# 14       76812      MDU6TGFiZWw3NjgxMg==
# 15   307649777  MDU6TGFiZWwzMDc2NDk3Nzc=
# 16       76811      MDU6TGFiZWw3NjgxMQ==
# 17  1954720290  MDU6TGFiZWwxOTU0NzIwMjkw
# 18      127685      MDU6TGFiZWwxMjc2ODU=
# 19    48070600  MDU6TGFiZWw0ODA3MDYwMA==
# 20    76939933  MDU6TGFiZWw3NjkzOTkzMw==
# 21      127681      MDU6TGFiZWwxMjc2ODE=
# ...

# %%
#solution2
import requests
url = 'https://api.github.com/repos/pandas-dev/pandas/issues'
resp=requests.get(url)
data=resp.json()
df28=pd.DataFrame(data,columns=['labels'])

x=[]
for i in range(len(df28)):
    if len(df28['labels'][i])==0:
        y={
            'id':'',
            'node_id':"",
            'url':"",
            'name':'',
            'color':'',
            'default':'',
            'description':''
        }
        x.append(y)
    elif len(df28['labels'][i])!=0:
        for j in range(len(df28['labels'][i])):
            x.append(df28['labels'][i][j])
pd.DataFrame(x)
# Out:
#             id                   node_id  \
# 0
# 1
# 2       134699      MDU6TGFiZWwxMzQ2OTk=
# 3     48070600  MDU6TGFiZWw0ODA3MDYwMA==
# 4     48070600  MDU6TGFiZWw0ODA3MDYwMA==
# 5        76811      MDU6TGFiZWw3NjgxMQ==
# 6      2822098      MDU6TGFiZWwyODIyMDk4
# 7     71268330  MDU6TGFiZWw3MTI2ODMzMA==
# 8        76811      MDU6TGFiZWw3NjgxMQ==
# 9   1954720290  MDU6TGFiZWwxOTU0NzIwMjkw
# 10      127685      MDU6TGFiZWwxMjc2ODU=
# 11   150096370  MDU6TGFiZWwxNTAwOTYzNzA=
# 12       76811      MDU6TGFiZWw3NjgxMQ==
# 13  1954720290  MDU6TGFiZWwxOTU0NzIwMjkw
# 14     8935311      MDU6TGFiZWw4OTM1MzEx
# 15  1954720290  MDU6TGFiZWwxOTU0NzIwMjkw
# 16       76812      MDU6TGFiZWw3NjgxMg==
# 17   307649777  MDU6TGFiZWwzMDc2NDk3Nzc=
# 18       76811      MDU6TGFiZWw3NjgxMQ==
# 19  1954720290  MDU6TGFiZWwxOTU0NzIwMjkw
# 20      127685      MDU6TGFiZWwxMjc2ODU=
# 21    48070600  MDU6TGFiZWw0ODA3MDYwMA==
# 22    76939933  MDU6TGFiZWw3NjkzOTkzMw==
# 23      127681      MDU6TGFiZWwxMjc2ODE=
# ...

# %%
#solution 3
import requests
url = 'https://api.github.com/repos/pandas-dev/pandas/issues'
#resp=requests.get(url)
data=pd.read_json(url)
df=pd.DataFrame(data,columns=['number','title',
                              'user','state','label'])

#split keys and values in column
import json
from pandas.io.json import json_normalize
user_data=json_normalize(data['user'])

#concating both data set to display all column
df3=pd.concat([data[:],user_data[:]],axis=1)
df3.head()

#not selecting user column since split
df4=pd.concat([data[['number','title','state']],user_data[:]],axis=1)
df4.head()
# Out:
# /var/folders/70/xyz7khq54gx8qklx52wtt6tw0000gn/T/ipykernel_5567/3479552509.py:12: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#   user_data=json_normalize(data['user'])
#    number                                              title state  \
# 0   46162  Bug Fix GroupBy.describe produces inconsistent...  open
# 1   46161                              Update test_fillna.py  open
# 2   46160  Backport PR #46124 on branch 1.4.x (DOC: Impro...  open
# 3   46159  Backport PR #45902 on branch 1.4.x (Use Mamba ...  open
# 4   46158  Backport PR #46118 on branch 1.4.x (CI: Align ...  open
#
#              login        id               node_id  \
# 0          weikhor  36619387  MDQ6VXNlcjM2NjE5Mzg3
# 1          weikhor  36619387  MDQ6VXNlcjM2NjE5Mzg3
# 2  meeseeksmachine  39504233  MDQ6VXNlcjM5NTA0MjMz
# 3  meeseeksmachine  39504233  MDQ6VXNlcjM5NTA0MjMz
# 4  meeseeksmachine  39504233  MDQ6VXNlcjM5NTA0MjMz
#
# ...

# %% [markdown]
# # Load Data from sqllite, sql, mongodb

# %%
import sqlite3
#connecting with the database.
db = sqlite3.connect("my_database4.db")
# Drop table if it already exist using execute() method.
db.execute("drop table if exists test")
query = """
CREATE TABLE test
(a VARCHAR(20), b VARCHAR(20),
 c REAL,        d INTEGER
);"""
con = sqlite3.connect('mydata2.sqlite')
#con.execute(query)
con.commit()

# %%
data = [('Atlanta', 'Georgia', 1.25, 6),
        ('Tallahassee', 'Florida', 2.6, 3),
        ('Sacramento', 'California', 1.7, 5)]
stmt = "INSERT INTO test VALUES(?, ?, ?, ?)"
con.executemany(stmt, data)
con.commit()

# %%
cursor = con.execute('select * from test')
rows = cursor.fetchall()
rows
# Out:
# [('Atlanta', 'Georgia', 1.25, 6),
#  ('Tallahassee', 'Florida', 2.6, 3),
#  ('Sacramento', 'California', 1.7, 5),
#  ('Atlanta', 'Georgia', 1.25, 6),
#  ('Tallahassee', 'Florida', 2.6, 3),
#  ('Sacramento', 'California', 1.7, 5)]

# %%
cursor.description
pd.DataFrame(rows, columns=[x[0] for x in cursor.description])
# Out:
#              a           b     c  d
# 0      Atlanta     Georgia  1.25  6
# 1  Tallahassee     Florida  2.60  3
# 2   Sacramento  California  1.70  5
# 3      Atlanta     Georgia  1.25  6
# 4  Tallahassee     Florida  2.60  3
# 5   Sacramento  California  1.70  5

# %%
#!/usr/bin/python
import sqlite3
#connecting with the database.
db = sqlite3.connect("my_database5.db")
# Drop table if it already exist using execute() method.
db.execute("drop table if exists grades1")
# Create table as per requirement
db.execute("create table grades1(id int, name text, score int)")
#inserting values inside the created table
db.execute("insert into grades1(id, name, score) values(101, 'John',99 )")
db.execute("insert into grades1(id, name, score) values(102, 'Gary',90 )")
db.execute("insert into grades1(id, name, score) values(103, 'James', 80 )")
db.execute("insert into grades1(id, name, score) values(104, 'Cathy', 85 )")
db.execute("insert into grades1(id, name, score) values(105, 'Kris',95 )")

# %%
db.commit()

# %%
results = db.execute("select * from grades1 order by id")
for row in results:
    print((row))
print("-" * 60 )
# Out:
# (101, 'John', 99)
# (102, 'Gary', 90)
# (103, 'James', 80)
# (104, 'Cathy', 85)
# (105, 'Kris', 95)
# ------------------------------------------------------------

# %%
results = db.execute("select * from grades1 where name = 'Gary' ")
for row in results: print(row)
print("-"* 60 )
# Out:
# (102, 'Gary', 90)
# ------------------------------------------------------------

# %%
results = db.execute("select * from grades1 where score >= 90 ")
for row in results:
    print(row)
print("-" * 60 )
# Out:
# (101, 'John', 99)
# (102, 'Gary', 90)
# (105, 'Kris', 95)
# ------------------------------------------------------------

# %%
results = db.execute("select name, score from grades1 order by score desc ")
for row in results:
    print(row)
print("-" * 60 )
# Out:
# ('John', 99)
# ('Kris', 95)
# ('Gary', 90)
# ('Cathy', 85)
# ('James', 80)
# ------------------------------------------------------------

# %%
results = db.execute("select name, score from grades1 order by score")
for row in results:
    print(row)
print("-" * 60 )
# Out:
# ('James', 80)
# ('Cathy', 85)
# ('Gary', 90)
# ('Kris', 95)
# ('John', 99)
# ------------------------------------------------------------

# %%
results = db.execute("select name, score from grades1 order by score")
for row in results:
    print(row)
# Out:
# ('James', 80)
# ('Cathy', 85)
# ('Gary', 90)
# ('Kris', 95)
# ('John', 99)
